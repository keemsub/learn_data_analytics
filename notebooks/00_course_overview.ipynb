# %% [markdown]
# # 데이터 분석 교육 자료
#
# 이 노트북은 파이썬 기초부터 데이터 분석, 시각화, 머신러닝까지 학습하는 데 사용합니다.
#
# - Python 기본 문법
# - 통계 기초
# - pandas 활용
# - Matplotlib / Seaborn 시각화
# - 회귀와 분류 모델

# %%
import pandas as pd
import matplotlib.pyplot as plt

sales_df = pd.read_csv('../data/sample_sales.csv')
print(sales_df.head())
print('\n기본 통계:')
print(sales_df.describe())

# %% [markdown]
# ## 학습 순서
#
# 1. Python 기초
# 2. 기초 통계
# 3. pandas 실습
# 4. 시각화
# 5. 회귀 및 분류
# 6. 종합 프로젝트
